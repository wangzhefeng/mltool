# %% [markdown]
# [Kernel](https://www.kaggle.com/apapiu/regularized-linear-models)
#
# * 很少的特征工程；
# * 效果还不错；
# * 关键点：将数值型变量进行`log`转换；
#
# * Models
#     - ridge
#     - lasso

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### 1.读取训练数据和测试数据

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
train.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
all = pd.concat([train.loc[:, 'MSSubClass':'SaleCondition'], test.loc[:, 'MSSubClass':'SaleCondition']])
all.head(6)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
# 5          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
# ...

# %% [markdown]
# ### 2.数据预处理
#
# * 对偏态分布的数值型特征进行 $log(x + 1)$ 转换；
# * 对类别型特征生成哑变量(dummy variables);
# * 对含缺失值的数值型变量用各自特征的均值进行填充。

# %% [markdown]
# #### 目标变量：SalePrice(numeric)

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
prices = pd.DataFrame({'price': train['SalePrice'], 
                       'log(price + 1)': np.log1p(train['SalePrice'])})
prices.hist();

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

# %% [markdown]
# #### 数值型特征变换

# %%
# 特征的数据类型
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(all.dtypes)
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1       float64
# BsmtFinType2      object
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# ...

# %%
numeric_features = all.dtypes[all.dtypes != 'object'].index
numeric_features
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
skewed_features = train[numeric_features].apply(lambda x: skew(x.dropna()))
skewed_features = skewed_features[np.abs(skewed_features) > 0.75]
skewed_features = skewed_features.index
print(skewed_features)
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtHalfBath', 'KitchenAbvGr',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal'],
#       dtype='object')

# %%
all[skewed_features] = np.log1p(all[skewed_features])
# Out:
#       MSSubClass  LotFrontage    LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0       4.110874     4.189655   9.042040    5.283204    6.561031    0.000000
# 1       3.044522     4.394449   9.169623    0.000000    6.886532    0.000000
# 2       4.110874     4.234107   9.328212    5.093750    6.188264    0.000000
# 3       4.262680     4.110874   9.164401    0.000000    5.379897    0.000000
# 4       4.110874     4.442651   9.565284    5.860786    6.486161    0.000000
# 5       3.931826     4.454347   9.555064    0.000000    6.597146    0.000000
# 6       3.044522     4.330733   9.218804    5.231109    7.222566    0.000000
# 7       4.110874          NaN   9.247925    5.484797    6.756932    3.496508
# 8       3.931826     3.951244   8.719481    0.000000    0.000000    0.000000
# 9       5.252273     3.931826   8.912069    0.000000    6.747587    0.000000
# 10      3.044522     4.262680   9.323758    0.000000    6.810142    0.000000
# ...

# %% [markdown]
# #### 类别型数据生成哑变量

# %%
all = pd.get_dummies(all)

# %% [markdown]
# #### 缺失值填充

# %%
all = all.fillna(all.mean())

# %% [markdown]
# #### 输入模型的数据

# %%
x_train = all[:train.shape[0]]
x_test = all[train.shape[0]:]
y = train.SalePrice

# %% [markdown]
# ### 3.建立模型进行预测
#
# * $L_1$ regularized linear regression: LASSO
# * $L_2$ regularized linear regression: Ridge Regression
# * XGBoost

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, Lasso, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

def rmse_cv(model, x_train, y, cv_num):
    cv_score = cross_val_score(model, x_train, y, scoring = 'neg_mean_squared_error', cv = cv_num)
    rmse = np.sqrt(- cv_score)
    return (rmse)

# %% [markdown]
# ### Ridge Regression with Cross-Validation

# %% [markdown]
# Model Selection:

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
cv_ridge = [rmse_cv(model = Ridge(alpha = alpha), x_train = x_train, y = y, cv_num = 5).mean() for alpha in alphas]
cv_ridge = pd.Series(cv_ridge, index = alphas)

cv_ridge.plot(title = 'Validation - Just Do It')
plt.xlabel('alpha')
plt.ylabel('RMSE')
# Out:
# Text(0,0.5,'RMSE')

# %%
cv_ridge.min()
# Out:
# 0.12733734668670751

# %% [markdown]
# Prediction:

# %%
model_ridge = Ridge(alpha = 10)
model_ridge.fit(x_train, y)
pred_ridge = model_ridge.predict(x_test)
pred_ridge
# Out:
# array([11.68713201, 11.93842702, 12.10631979, ..., 12.05320284,
#        11.67259026, 12.3217596 ])

# %% [markdown]
# ### Lasso

# %%
# alphas = [0.0005, 0.001, 0.1, 1]
# cv_lasso = [rmse_cv(Lasso(alpha = alpha)).mean() for alpha in alphas]
# cv_lasso = pd.Series(cv_lasso, index = alphas)

# cv_lasso.plot(title = 'Validation - Lasso')
# plt.xlabel('alpha')
# plt.ylabel('RMSE')

# %%
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005])
model_lasso.fit(x_train, y)
rmse_cv(model_lasso).mean()
# Out:
# 0.12314421090977441

# %%
with pd.option_context('display.max_rows', 20, 'display.max_columns', None):
    coef = pd.Series(model_lasso.coef_, index = x_train.columns)
    print(coef)
# Out:
# MSSubClass              -0.007480
# LotFrontage              0.000000
# LotArea                  0.071826
# OverallQual              0.053160
# OverallCond              0.043027
# YearBuilt                0.001777
# YearRemodAdd             0.000722
# MasVnrArea              -0.000194
# BsmtFinSF1               0.009292
# BsmtFinSF2              -0.001385
#                            ...
# SaleType_ConLw          -0.000000
# SaleType_New             0.021575
# SaleType_Oth             0.000000
# SaleType_WD             -0.030656
# SaleCondition_Abnorml   -0.047116
# SaleCondition_AdjLand    0.000000
# SaleCondition_Alloca    -0.000000
# SaleCondition_Family    -0.007925
# SaleCondition_Normal     0.019666
# SaleCondition_Partial    0.000000
# Length: 288, dtype: float64

# %%
print('Lasso picked %s variables and eliminated the other %s variables' % 
      (str(sum(coef != 0)), str(sum(coef == 0))))
# Out:
# Lasso picked 110 variables and eliminated the other 178 variables

# %%
pred_lasso = np.expm1(model_lasso.predict(x_test))
pred_lasso
# Out:
# array([119958.03568086, 151482.56732178, 180200.85364774, ...,
#        169023.5480817 , 118942.41768702, 228403.15457007])

# %%
imp_coef = pd.concat([coef.sort_values().head(10), coef.sort_values().tail(10)])
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = 'barh')
plt.title('Coefficients in the Lasso Model')
# Out:
# Text(0.5,1,'Coefficients in the Lasso Model')

# %%
# residuals
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)

preds = pd.DataFrame({
    'preds': model_lasso.predict(x_train),
    'true': y
})
preds['residuals'] = preds['true'] - preds['preds']
preds.plot(x = 'preds', y = 'residuals', kind = 'scatter')

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(x_train, label = y)
dtest = xgb.DMatrix(x_test)

params = {
    'max_depth': 2,
    'eta': 0.1
}
model = xgb.cv(params, dtrain, num_boost_round = 500, early_stopping_rounds = 100)
model.loc[30:, ['test-rmse-mean', 'train-rmse-mean']].plot()
# Out:
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:04:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# ...

# %%
model_xgb = xgb.XGBRegressor(n_estimators = 360, max_depth = 2, learning_rate = 0.1)
model_xgb.fit(x_train, y)

pred_xgb = np.expm1(model_xgb.predict(x_test))

# %%
preds = 0.7 * pred_lasso + 0.3 * pred_xgb

# %%
solution = pd.DataFrame({
    'id': test.Id, 
    'SalePrice': preds
})
solution.to_csv('ridge_sol.csv', index = False)
